# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:\Users\Hinal\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(3)
# Out:
# <ipython-input-2-53ae5f6c69c5>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\Hinal\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# Opening the google images
url = "https://www.amazon.in/"
driver.get(url)

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Finding the search bar using it's xpath
search_bar.send_keys(" women sarees")       # Inputing "sarees" keyword to search images
# Out:
# <ipython-input-4-62a8371c4415>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Finding the search bar using it's xpath

# %%
search_button = driver.find_element_by_id("nav-search-submit-button")    # Finding the xpath of search button
search_button.click()        # Clicking the search button
# Out:
# <ipython-input-5-196ba4292f54>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_button = driver.find_element_by_id("nav-search-submit-button")    # Finding the xpath of search button

# %%
images = driver.find_elements_by_xpath('//img[@class="s-image"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
            
for i in range(len(img_urls)):
    if i >= 100:
        break
    print("Downloading {0} of {1} images" .format(i, 200))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\Hinal\Downloads\fr_images/Saree" +str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# <ipython-input-8-276f1aa0cb34>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_xpath('//img[@class="s-image"]')
# ...

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Finding the search bar using it's xpath
search_bar.send_keys("men jeans")       # Inputing "jeans" keyword to search images
search_button = driver.find_element_by_id("nav-search-submit-button")    # Finding the xpath of search button
search_button.click()        # Clicking the search button
images = driver.find_elements_by_xpath('//img[@class="s-image"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
            
for i in range(len(img_urls)):
    if i >= 200:
        break
    print("Downloading {0} of {1} images" .format(i, 100))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\Hinal\Downloads\fr_images\Saree" +str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# <ipython-input-9-c1e3ecb81c7b>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Finding the search bar using it's xpath
# <ipython-input-9-c1e3ecb81c7b>:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_button = driver.find_element_by_id("nav-search-submit-button")    # Finding the xpath of search button
# <ipython-input-9-c1e3ecb81c7b>:5: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_xpath('//img[@class="s-image"]')
# ...

# %%
search_button = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[66]/span/div/div/ul/li[7]/a')       # Locating search_button by xpath
search_button.click()
images = driver.find_elements_by_xpath('//img[@class="s-image"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
            
for i in range(len(img_urls)):
    if i >= 200:
        break
    print("Downloading {0} of {1} images" .format(i, 100))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\Hinal\Downloads\fr_images\Saree" +str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# <ipython-input-15-c0146b58459a>:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_xpath('//img[@class="s-image"]')
# ...

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Finding the search bar using it's xpath
search_bar.send_keys("men jeans")       # Inputing "jeans" keyword to search images
search_button = driver.find_element_by_id("nav-search-submit-button")    # Finding the xpath of search button
search_button.click()        # Clicking the search button
images = driver.find_elements_by_xpath('//img[@class="s-image"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
            
for i in range(len(img_urls)):
    if i >= 200:
        break
    print("Downloading {0} of {1} images" .format(i, 100))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\Hinal\Downloads\fr_images\Jeans" +str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# <ipython-input-13-c1e3ecb81c7b>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Finding the search bar using it's xpath
# <ipython-input-13-c1e3ecb81c7b>:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_button = driver.find_element_by_id("nav-search-submit-button")    # Finding the xpath of search button
# <ipython-input-13-c1e3ecb81c7b>:5: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_xpath('//img[@class="s-image"]')
# ...

# %%
search_button = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[63]/span/div/div/ul/li[7]/a')       # Locating search_button by xpath
search_button.click()
images = driver.find_elements_by_xpath('//img[@class="s-image"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
            
for i in range(len(img_urls)):
    if i >= 200:
        break
    print("Downloading {0} of {1} images" .format(i, 100))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\Hinal\Downloads\fr_images\Jeans" +str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# <ipython-input-20-49530c74235c>:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_xpath('//img[@class="s-image"]')
# ...

# %%
search_button = driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[63]/span/div/div/ul/li[7]")    # Finding the xpath of search button
search_button.click() 
images = driver.find_elements_by_xpath('//img[@class="s-image"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
            
for i in range(len(img_urls)):
    if i >= 200:
        break
    print("Downloading {0} of {1} images" .format(i, 100))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\Hinal\Downloads\fr_images\Jeans" +str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# <ipython-input-21-e65a4163d0ef>:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_xpath('//img[@class="s-image"]')
# ...

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Finding the search bar using it's xpath
search_bar.send_keys("men trouser")       # Inputing "shirt" keyword to search image
search_button = driver.find_element_by_id("nav-search-submit-button")    # Finding the xpath of search button
search_button.click() 
images = driver.find_elements_by_xpath('//img[@class="s-image"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
            
for i in range(len(img_urls)):
    if i >= 100:
        break
    print("Downloading {0} of {1} images" .format(i, 100))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\Hinal\Downloads\fr_images\Trouser" +str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# <ipython-input-22-c06181d37cf7>:5: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_xpath('//img[@class="s-image"]')
# ...

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Finding the search bar using it's xpath
search_bar.send_keys("trouser")       # Inputing "shirt" keyword to search image
search_button = driver.find_element_by_id("nav-search-submit-button")    # Finding the xpath of search button
search_button.click() 
images = driver.find_elements_by_xpath('//img[@class="s-image"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
            
for i in range(len(img_urls)):
    if i >= 100:
        break
    print("Downloading {0} of {1} images" .format(i, 100))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\Hinal\Downloads\fr_images\Trouser" +str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# <ipython-input-26-e29838410760>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Finding the search bar using it's xpath
# <ipython-input-26-e29838410760>:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_button = driver.find_element_by_id("nav-search-submit-button")    # Finding the xpath of search button
# <ipython-input-26-e29838410760>:5: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_xpath('//img[@class="s-image"]')
# ...

# %%
search_button = driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[64]/span/div/div/ul/li[7]/a")    # Finding the xpath of search button
search_button.click() 
images = driver.find_elements_by_xpath('//img[@class="s-image"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
            
for i in range(len(img_urls)):
    if i >= 100:
        break
    print("Downloading {0} of {1} images" .format(i, 100))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\Hinal\Downloads\fr_images\Trouser" +str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# <ipython-input-23-9158dffa1075>:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_xpath('//img[@class="s-image"]')
# ...

# %%
search_button = driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[64]/span/div/div/ul/li[7]/a")    # Finding the xpath of search button
search_button.click() 
images = driver.find_elements_by_xpath('//img[@class="s-image"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
            
for i in range(len(img_urls)):
    if i >= 100:
        break
    print("Downloading {0} of {1} images" .format(i, 100))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\Hinal\Downloads\fr_images\Trouser" +str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# <ipython-input-25-4e21b23e065f>:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_xpath('//img[@class="s-image"]')
# ...

# %%
driver.quit()
